# %%
import os
from PyPDF2 import PdfReader
from docx import Document

# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# Function to extract text from DOCX
def extract_text_from_docx(docx_path):
    doc = Document(docx_path)
    text = ""
    for para in doc.paragraphs:
        text += para.text
    return text

# Function to extract text from any CV file (PDF or DOCX)
def extract_text_from_file(file_path):
    if file_path.endswith('.pdf'):
        return extract_text_from_pdf(file_path)
    elif file_path.endswith('.docx'):
        return extract_text_from_docx(file_path)
    else:
        raise ValueError(f"Unsupported file format: {file_path}")

# Extract text from all CV files in the folder
cv_folder = 'cv_folder'
cv_texts = {}

for filename in os.listdir(cv_folder):
    file_path = os.path.join(cv_folder, filename)
    if os.path.isfile(file_path):
        try:
            text = extract_text_from_file(file_path)
            cv_texts[filename] = text
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Print extracted texts for review (optional)
for filename, text in cv_texts.items():
    print(f"\nText from {filename}:")
    print(text[:500])  # Show first 500 characters for preview
# Out:
# Text from Careers - ANUPA DINURANGA.pdf:
#
# DevOps enthusiast with a strong focus on cloud computing, automation, and application security.
# Experienced in building scalable systems and implementing continuous integration/continuous
# deployment (CI/CD) pipelines. Hands -on expertise in AWS, Docker, Jenkins, Terraform,  Linux  and
# Kubernetes. Skilled in designing secure, reliable systems with a passion for continuous learning and
# innovation.
# CI/CD Pipeline with Jenkins, SonarQube, Docker, and AWS EC2
#
# • Developed an automated CI/C
#
# Text from Careers - Danushka Sehan.pdf:
# Tools and Technologies
# SUMMARY
# Passionate and driven Computer Engineering student with a strong interest in DevOps, cloud
# technologies, robotics, and IoT. With strong communication skills and a proven ability to collaborate
# effectively within teams, I am committed to contributing positively to any project or organization I
# am a part of.
# PROJECTS
# PROFESSIONAL SKILLS
# Languages
# Python
# Bash
# Java
# C++
# Dart
# JavaScript
# SQLDeveloping a cloud-based CI/CD pipeline using AWS, Kubernetes, Jenkins, Docker,
#
# Text from Careers - Dhanika Kumarasiri.pdf:
# 077 161 8093
# 99/23, Ramahera Road, Kaduwela
# Dhanika Kumarasiri/Medium
# Dhanika Kumarasiri/Linkedin
# Dhanika Kumarasiri/Githubdhanikaanupama2000@gmail.comDHANIKA
# KUMARASIRI
# DevOps/ Cloud
# Intern
# TEC H N IC A L SKILLS
# AWS
# Git & Github
# Docker
# Linux
# Bash
# NGINX
# Terraform
# Kubernetes
# Python
# MySQL
# Springboot
# React Js
# MongoDB Atlas
# Java
# PHP
# HTML
# CSS
# CC O N TA C T A BO UT
# As a dedicated Software Engineering Undergraduate with a strong focus on
# DevOps,  I bring a robust set of skills including teamwork, co
#
# Text from Careers - Dhanuja Perera CV.pdf:
# DHANUJA
# THARUKAMobile: +94729870087
# Email: dhanujatharuka@gmail.com
# Address: 235/A/2, Kekirideniya Rd,
# Hewagama, Kaduwela, Sri Lanka
# LinkedIn: Dhanuja Tharuka
# SUMMARY
# Motivated IT security professional with hands-on experience supporting Linux and Windows environ-
# ments in a major financial institution. Familiar with deploying and managing Antivirus solutions,
# EDRs, IDS/IPS, and vulnerability scanning tools. Solid understanding of core cybersecurity concepts,
# ethical hacking, and networking fund
#
# Text from Careers - HASEEF AHAMED.pdf:
# HASEEF AHAMED
# Infrastruture Engineer – Intern  @ Enadoc Pvt Ltd
# mshaseefat@gmail.com  | +94 772939059 | LinkedIn  | Colombo
#
# Objective
# A highly motivated Infrastructure Engineer Intern with hands -on experience in optimizing system
# performance, automating deployments, and ensuring high availability across cloud environments. Proficient
# in Docker, Azure DevOps, Kubernetes, and container tec hnologies, with a strong foundation in infrastructure -
# as-code tools like Terraform. With a bac
#
# Text from Careers - Isuru Piyumal.pdf:
# Isuru Piyumal
# Computer Science Undergraduate | UCSC
# +94 76 806 7755  |  isupiyumal@gmail.com  |  LinkedIn
#
# SUMMARY  Proactive Computer Science undergraduate with hands -on experience in cloud
# computing, automation, and DevOps practices. Skilled in creating CI/CD pipelines,
# containerized deployments, and infrastructure monitoring with a strong foundation in
# cloud platforms like Azure and AWS. Proficient in writing efficient scripts and implementing
# automated solutions to streamline pro
#
# Text from Careers - Madhushan Deshapriya.pdf:
# SUMMARY
# EDUCATION
# PROJECTSMADHUSHAN DESHAPRIYA
# I’m Madhushan Deshapriya, a driven 4th-year Computer Science student at NSBM Green
# University. My passion lies in transforming complex challenges into practical software solutions
# through methodical problem-solving and hands-on experimentation. With a focus on full-stack
# development and AI-driven applications, I aim to contribute creatively as a Software Engineer
# Intern while embracing growth in a collaborative environment.
# Bachelor of Science in Co
#
# Text from Careers - Maryam Mawsoon.pdf:
#
#  325, Kandy road, mawanella  |  maryammawsoon67@gmail.com  |  +94 76 055 5859
# linkedin.com/in/maryam -mashkoora -975204249
# OBJECTIVE
# A motivated and diligent computer science student is looking for a DevOps internship to capitalize on their core
# knowledge of automation, cloud platforms, and CI/CD tools.  eager to help optimize deployment pipelines, optimize
# infrastructure, and obtain practical expertise in supporting robust, scalable systems. devoted to acquiring and utilizing
# DevOps
#
# Text from Careers - Movindu Liyanage.pdf:
# Movindu Liyanage
# ♂¶ap-¶arker-altColombo,Sri Lanka /envel⌢pemovinliyanage@gmail.com ♂phone-alt+94 71 35 05 391 ὑ7movin.dev /linkedin-inmovinduliyanage
# /githubMovin21
# Profile
# Third-year Software Engineering student with a strong foundation in full-stack development and growing enthusiasm
# for DevOps practices. Experience leading university project teams while implementing Agile methodologies and ver-
# sion control systems. Proficient in Linux environments and familiar with Terraform for infrastructu
#
# Text from Careers - Prabhash Pramodha (1).pdf:
# 123 Anywhere St., Any City
# Leo Book (Ongoing) -  Project Management system for Leo ClubsMy personal portfolio websiteprabhashpramodha99@gmail.comPrabhash Pramodha
# PROFILE
# 2022 - 2026B.Sc. Information Technology Honours(Undergraduate)
# +94 77 971 6654
# 53/3, Chilaw Rd, Andigama.github.com/PrabhashLiyanage99
# linkedin.com/in/prabhash-pramodha
# Highly motivated full-stack web developer and mobile app developer with a passion for learning and staying up-to-
# date with emerging technologies. Eager to appl
