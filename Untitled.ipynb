# %%
import os
import pinecone
import requests
from PyPDF2 import PdfReader
from docx import Document
from azure.ai.ml import MLClient
from azure.core.exceptions import HttpResponseError
from azure.identity import DefaultAzureCredential

# Load environment settings (you can configure this dynamically later)
environment = "dev"  # 'dev', 'staging', or 'prod'

# %%
import os
from pinecone import Pinecone, ServerlessSpec

# Initialize Pinecone using the new approach
pc = Pinecone(
    api_key=os.getenv("PINECONE_API_KEY", "")
)

# Create an index if it doesn't already exist
index_name = 'cv-analyzer-index'
if index_name not in pc.list_indexes().names():
    pc.create_index(
        name=index_name,
        dimension=768,  # Ensure the dimension matches your embedding size
        metric='euclidean',
        spec=ServerlessSpec(
            cloud='gcp',
            region='us-west1'
        )
    )

# Connect to the index
index = pc.index(index_name)
# Out:
# ---------------------------------------------------------------------------
# NotFoundException                         Traceback (most recent call last)
# Cell In[2], line 12
#      10 index_name = 'cv-analyzer-index'
#      11 if index_name not in pc.list_indexes().names():
# ---> 12     pc.create_index(
#      13         name=index_name,
#      14         dimension=768,  # Ensure the dimension matches your embedding size
#      15         metric='euclidean',
#      16         spec=ServerlessSpec(
#      17             cloud='gcp',
#      18             region='us-west1'
#      19         )
#      20     )
#      22 # Connect to the index
#      23 index = pc.index(index_name)
#
# File ~\anaconda3\Lib\site-packages\pinecone\control\pinecone.py:143, in Pinecone.create_index(self, name, spec, dimension, metric, timeout, deletion_protection, vector_type, tags)
#     123 def create_index(
#     124     self,
#     125     name: str,
#    (...)
# ...

# %%
# Function to extract text from PDF
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PdfReader(file)
        text = ""
        for page in reader.pages:
            text += page.extract_text()
    return text

# Function to extract text from DOCX
def extract_text_from_docx(docx_path):
    doc = Document(docx_path)
    text = ""
    for para in doc.paragraphs:
        text += para.text
    return text

# Function to extract text from any CV file (PDF or DOCX)
def extract_text_from_file(file_path):
    if file_path.endswith('.pdf'):
        return extract_text_from_pdf(file_path)
    elif file_path.endswith('.docx'):
        return extract_text_from_docx(file_path)
    else:
        raise ValueError(f"Unsupported file format: {file_path}")

# Extract text from all CV files in the folder
cv_folder = './cv_folder'  # Adjust path if necessary
cv_texts = {}

for filename in os.listdir(cv_folder):
    file_path = os.path.join(cv_folder, filename)
    if os.path.isfile(file_path):
        try:
            text = extract_text_from_file(file_path)
            cv_texts[filename] = text
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Print a preview of extracted texts for review
for filename, text in cv_texts.items():
    print(f"\nText from {filename}:")
    print(text[:500])  # Show first 500 characters for preview

# %%
# Placeholder function to generate embeddings (you can replace this with a real embedding model)
def generate_embeddings(text):
    # Example: Using a pre-trained transformer model for text embedding (like GPT, BERT, etc.)
    # Replace this with actual code for embedding generation, such as using Huggingface, OpenAI API, etc.
    return [0.0] * 768  # Dummy embedding for demonstration

# Generate embeddings for each CV text
cv_embeddings = {}
for filename, text in cv_texts.items():
    embedding = generate_embeddings(text)
    cv_embeddings[filename] = embedding

# Print the embeddings (optional)
print(cv_embeddings)

# %%
# Upload CV data and embeddings to Pinecone
for filename, embedding in cv_embeddings.items():
    # Format data for Pinecone
    index.upsert([(filename, embedding)])

print("CV data and embeddings successfully uploaded to Pinecone!")
